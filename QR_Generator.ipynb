# %%
# !pip install pypng
# Out:
# ...
#      |████████████████████████████████| 649 kB 5.1 MB/s
# ...
#   Created wheel for pypng: filename=pypng-0.0.20-py3-none-any.whl size=67177 sha256=9c1e2bccd6325ba6b9dd593d4cdc768d937ab03cfe73235daac5f09d78319bd8
#   Stored in directory: /root/.cache/pip/wheels/54/64/43/dfd10cf95dc1687dc5350e861321ecd9a5d76b7c3d96fa1dc6
# Successfully built pypng
# ...

# %%
import pyqrcode
import png
from pyqrcode import QRCode

# %%
#getting QR Code link from the user
link= input("Enter the link for QR ")
#generate QR
qr=pyqrcode.create(link)

#save QR as png
qr.png("myqr.png",scale= 6)
